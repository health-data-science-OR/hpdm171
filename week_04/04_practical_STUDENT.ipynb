# %% [markdown]
# # Consolidation Week: Exercises
#
# These exercises accompany `05_Consolidation_Lecture.ipynb` and revise **Weeks 1–3**: loops, conditionals, functions, scope, and dictionaries.
#
# Most exercises are reused (in some cases lightly adapted) from the Week 1–2–3 practicals, so this is a good opportunity to revisit anything you found tricky the first time round. One exercise (Exercise 5) is new and focuses specifically on **scope**, which did not have a dedicated exercise in the earlier practicals.
#
# > Please use the `hds_python` environment, as with the other course materials.

# %% [markdown]
# 🎓 In this set of exercises you will practise:
#
# * ✅ `while` loops (Exercise 1)
# * ✅ combining conditionals, functions, and loops (Exercise 2)
# * ✅ nested loops (Exercise 3)
# * ✅ updating and safely querying dictionaries (Exercise 4)
# * ✅ variable and function scope **new exercise** (Exercise 5)
# * ✅ bringing loops, functions, conditionals, and dictionaries together (Exercise 6)

# %% [markdown]
# ## Exercise 1: Oxygen saturation monitoring (`while` loop)
#
# A patient's oxygen saturation starts at 88%. Each hour it improves by 2 percentage points. Monitoring stops when the target value of 94% is reached.
#
# Write a `while` loop that:
# - prints the oxygen saturation each hour
# - counts the number of hours taken
# - prints a final message when the target is reached

# %%
spo2 = 88
hour = 0
target_spo2 = 94

# your code here ...

# %% [markdown]
# ## Exercise 2: Counting abnormal heart rates
#
# Write a function called `heart_rate_in_normal_range(heart_rate_bpm)` that returns `True` if a resting heart rate is within the normal range of 60 to 100 bpm inclusive.
#
# Then write a second function called `count_abnormal_heart_rates(heart_rates)` that:
# - accepts a list of heart-rate values
# - counts how many are outside the normal resting range (call your first function inside a loop)
# - returns that count
#
# Test it on:
# ```python
# heart_rates = [72, 110, 58, 95, 102, 67]
# ```

# %%
def heart_rate_in_normal_range(heart_rate_bpm):
    """Return True if resting heart rate is within the normal range."""
    # your code here ...
    pass

# %%
def count_abnormal_heart_rates(heart_rates):
    """Return a count of heart rates outside the normal resting range."""
    # your code here ...
    pass

# %%
heart_rates = [72, 110, 58, 95, 102, 67]
print(count_abnormal_heart_rates(heart_rates))
# Out:
# None

# %% [markdown]
# ## Exercise 3: Nested loops. Ward bays and beds
#
# Suppose a ward has 3 bays and each bay has 4 beds.
#
# Write nested `for` loops that print:
#
# ```python
# Bay 1, Bed 1
# Bay 1, Bed 2
# ...
# Bay 3, Bed 4
# ```

# %%
# your code here ...

# %% [markdown]
# ## Exercise 4: Update and query a patient record (dictionaries)
#
# A new set of clinical observations has just been recorded for a patient.
#
# **Task 1:** Write a function called `add_observations(patient_record, observations)`.
#
# Rules:
# - `observations` is a dictionary that may contain keys such as `"heart_rate"`, `"oxygen_saturation"`, `"temperature"`
# - use `.update()` to add all observations to the patient record in one step
# - return the updated dictionary
#
# **Task 2:** Write a function called `get_observation(patient_record, key, default="not recorded")`.
#
# Rules:
# - use `.get()` to safely look up `key` in the patient record
# - if the key is not present, return `default`
# - return the value
#
# Test data:
# ```python
# patient = {"patient_id": 1003, "age": 45, "heart_rate": 88, "ward": "C1"}
#
# new_obs = {"heart_rate": 95, "oxygen_saturation": 98, "temperature": 37.2}
# patient = add_observations(patient, new_obs)
# print(patient)
#
# print(get_observation(patient, "temperature"))    # expected: 37.2
# print(get_observation(patient, "blood_pressure")) # expected: "not recorded"
# print(get_observation(patient, "ward"))            # expected: "C1"
# ```

# %%
def add_observations(patient_record, observations):
    """
    Add a dictionary of observations to a patient record and return it.

    Parameters
    ----------
    patient_record : dict
        An existing patient record dictionary.
    observations : dict
        Key-value pairs of clinical observations to add or overwrite.

    Returns
    -------
    dict
        The updated patient record.
    """
    # your code here ...
    pass

# %%
def get_observation(patient_record, key, default="not recorded"):
    """
    Safely retrieve a value from a patient record.

    Parameters
    ----------
    patient_record : dict
    key : str
    default : any, optional

    Returns
    -------
    any
    """
    # your code here ...
    pass

# %%
patient = {"patient_id": 1003, "age": 45, "heart_rate": 88, "ward": "C1"}

new_obs = {"heart_rate": 95, "oxygen_saturation": 98, "temperature": 37.2}
patient = add_observations(patient, new_obs)
print(patient)

print(get_observation(patient, "temperature"))
print(get_observation(patient, "blood_pressure"))
print(get_observation(patient, "ward"))
# Out:
# None
# None
# None
# None

# %% [markdown]
# ## Exercise 5: Debugging a scope problem (new exercise)
#
# This is a **new exercise** written for the consolidation week, since scope did not have a dedicated exercise in the Weeks 1–3 practicals. It builds directly on Section 7 of the consolidation lecture.
#
# A colleague has written the function below to flag whether a patient's heart rate is "high". It appears to work the first time it's called, but produces the **wrong answer** the second time.

# %%
threshold = 100

def is_high_heart_rate(heart_rate_bpm):
    """Return True if heart rate is above the notebook-level threshold."""
    return heart_rate_bpm > threshold

print(is_high_heart_rate(110))  # True, as expected

# Later in the analysis, a junior colleague adjusts the threshold
# for a different, more cautious patient group...
threshold = 130

print(is_high_heart_rate(110))  # uh oh - is this still correct?
# Out:
# True
# False

# %% [markdown]
# **Task 1:** In your own words, explain why the second call to `is_high_heart_rate(110)` returns a different answer, even though the argument `110` did not change. Which section of the consolidation lecture explains this behaviour?
#
# **Task 2:** Rewrite `is_high_heart_rate` so that it does **not** rely on any notebook-level (global) variable. Give the threshold a sensible **default value** of `100`, but allow the caller to override it.
#
# **Task 3:** Show that your fixed function now gives a **consistent, predictable** answer for `heart_rate_bpm=110` regardless of what any notebook-level variable called `threshold` is currently set to.

# %%
# Task 1: your explanation as a comment or short markdown note

# Task 2: your fixed function
def is_high_heart_rate_fixed(heart_rate_bpm, threshold=100):
    """Return True if heart rate is above threshold (default 100 bpm)."""
    # your code here ...
    pass

# %%
# Task 3: demonstrate the fixed function is unaffected by a global 'threshold'
threshold = 999  # this should have NO effect on the function below

print(is_high_heart_rate_fixed(110))              # uses the default threshold=100
print(is_high_heart_rate_fixed(110, threshold=130))  # caller can still override explicitly
# Out:
# None
# None

# %% [markdown]
# ## Exercise 6: Putting it together ward review summary
#
# This exercise combines everything from Exercises 1–5: functions, conditionals, loops, dictionaries, and writing self-contained functions (no reliance on notebook-level variables).
#
# You are given a list of patient dictionaries:
#
# ```python
# patients = [
#     {"name": "Asha", "heart_rate": 72, "days_since_last_attend": 3, "n_attends_last_year": 6},
#     {"name": "Ben", "heart_rate": 110, "days_since_last_attend": 30, "n_attends_last_year": 1},
#     {"name": "Chloe", "heart_rate": 58, "days_since_last_attend": 3, "n_attends_last_year": 1},
#     {"name": "David", "heart_rate": 88, "days_since_last_attend": 2, "n_attends_last_year": 7},
# ]
# ```
#
# **Task:**
#
# 1. Reuse your `heart_rate_in_normal_range()` function from Exercise 2.
# 2. Write a function `attendance_flag(days_since_last_attend, n_attends_last_year)` that returns `"frequent recent attender"` if the patient attended within the last 7 days **and** had 5 or more attendances in the last year, otherwise returns `"routine"`.
# 3. Loop through `patients` and build a list called `summaries`, where each entry is a one-line string such as:
#
# ```python
# Asha: heart rate normal, frequent recent attender
# ```
#
# 4. Print every summary.
#
# > Both functions should be self-contained (Exercise 5) — they should only use their parameters, not any notebook-level variable.

# %%
def attendance_flag(days_since_last_attend, n_attends_last_year):
    """Return an attendance flag based on recency and frequency of ED attendance."""
    # your code here ...
    pass

# %%
patients = [
    {"name": "Asha", "heart_rate": 72, "days_since_last_attend": 3, "n_attends_last_year": 6},
    {"name": "Ben", "heart_rate": 110, "days_since_last_attend": 30, "n_attends_last_year": 1},
    {"name": "Chloe", "heart_rate": 58, "days_since_last_attend": 3, "n_attends_last_year": 1},
    {"name": "David", "heart_rate": 88, "days_since_last_attend": 2, "n_attends_last_year": 7},
]

summaries = []

# your loop here ...

for line in summaries:
    print(line)

# %% [markdown]
# ## End
#
# Solutions to these exercises are provided in the accompanying `04_practical_SOLUTIONS.ipynb` notebook.
